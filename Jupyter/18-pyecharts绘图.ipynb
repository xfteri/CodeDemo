# %% [markdown]
# - 学习目标
# - 能够使用 pyecharts 进行基本绘图操作

# %% [markdown]
# # echarts和Pyecharts简介

# %% [markdown]
# - echarts 简介:
#
# - echarts 是一个使用 JavaScript 实现的开源可视化库，涵盖各行业图表，满足各种需求
# - echarts 遵循 Apache-2.0 开源协议，免费商用
# - echarts 兼容当前绝大部分浏览器（IE8/9/10/11、Chrome、Firefox、Safari等）及兼容多种设备，可随时随地任性展示-

# %% [markdown]
# - pyecharts 简介：
#
# - pyecharts 是一个用于生成 echarts 图表的 Python 开源类库
# - 使用 echarts 的绘图效果比 matplotlib 等更加炫酷

# %% [markdown]
# # Pyecharts 绘图案例

# %% [markdown]
# - 由于前面的内容基本已经介绍了常用可视化图表和各自的特点，下面通过一个案例来介绍 Pyecharts 的使用：
#
# - 案例中使用的 pyecharts 版本是 1.6.0 ，pyecharts 0.X版本和 1.X版本 API 变化较大，不能向下兼容，网上查资料的时候需要注意

# %% [markdown]
# ## 案例数据说明

# %% [markdown]
# - 案例使用从招聘网站（拉钩、智联、前程无忧、猎聘）上爬取的一周之内数据分析在招岗位数据
#
# - 分析目标：
#
# - 哪些公司在招聘数据分析，哪些城市数据分析的需求大，不同城市数据分析的薪资情况，数据分析对工作年限的要求，数据分析对学历的要求

# %%
import pandas as pd

# %% [markdown]
# ### 加载数据

# %%
job = pd.read_csv('./data/data_analysis_job.csv')
job.head()
# Out:
#        company_name                                                url  \
# 0      北京盛业恒泰投资有限公司  https://jobs.51job.com/beijing-cyq/104869885.h...
# 1  第一象限市场咨询（北京）有限公司  https://jobs.51job.com/beijing/122888080.html?...
# 2    北京超思电子技术有限责任公司  https://jobs.51job.com/beijing/123358754.html?...
# 3      北京麦优尚品科贸有限公司  https://jobs.51job.com/beijing-cyq/79448137.ht...
# 4        北京磐程科技有限公司  https://jobs.51job.com/beijing-cyq/123321410.h...
#
#    job_name city      salary experience               company_area  \
# 0   金融数据分析师   北京  6000-18000        NaN  金融/投资/证券,专业服务(咨询、人力资源、财会)
# 1     数据分析师   北京   5000-8000       1年经验  专业服务(咨询、人力资源、财会),互联网/电子商务
# 2  市场数据分析专员   北京  7000-10000       1年经验      电子技术/半导体/集成电路,医疗设备/器械
# 3     数据分析员   北京  8000-10000       1年经验  快速消费品(食品、饮料、化妆品),互联网/电子商务
# 4   金融数据分析师   北京  8000-10000       1年经验                   金融/投资/证券
#
#   company_size                                        description
# 0    500-1000人  北京盛业恒泰投资有限公司，注册资金1000万人民币，是一家一站式金融服务的大型企业，旗下有在...
# 1        少于50人  工作职责：1、协同团队完成客户委托的市场研究项目，包括项目的设计、执行、分析、报告撰写和汇报...
# 2    500-1000人  岗位职责：1、业务数据分析l编写月度、季度、年度业务数据分析报告，开展各类与业务销售数据分析...
# 3      50-150人  1、根据运营总监安排，实施具体数据分析工作。2、负责数据的审核工作，确保数据的准确性。3、总...
# 4      50-150人  1.人品端正，有责任心，愿与公司一同成长进步；2.以金融行业为最后的事业并为之奋斗一生;3....

# %%
# 查看数据形状
job.shape
# Out:
# (7926, 9)

# %%
# 查看数据字段
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7926 entries, 0 to 7925
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  7926 non-null   object
#  1   url           7926 non-null   object
#  2   job_name      7926 non-null   object
#  3   city          7926 non-null   object
#  4   salary        7926 non-null   object
#  5   experience    7208 non-null   object
#  6   company_area  7556 non-null   object
#  7   company_size  7838 non-null   object
#  8   description   7926 non-null   object
# dtypes: object(9)
# memory usage: 557.4+ KB

# %% [markdown]
# ## 哪些城市数据分析岗位多

# %% [markdown]
# ### 示例：获取招聘数据分析岗位最多的 TOP20 城市

# %%
city_job_list = job.groupby('city')['url'].count().sort_values(ascending=False)
city_job_top20 = city_job_list.head(20)
city_job_top20
# Out:
# city
# 北京    1608
# 上海    1176
# 广州    1033
# 深圳     820
# 杭州     395
# 成都     348
# 武汉     320
# 西安     248
# 南京     222
# 苏州     150
# 合肥     140
# 重庆     130
# 长沙     128
# 济南     123
# 郑州     114
# 太原     113
# 青岛      94
# 大连      94
# 东莞      83
# 无锡      81
# Name: url, dtype: int64

# %% [markdown]
# ### 使用 pyechart 绘制柱状图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

# %%
c = (
    Bar()# 创建柱状图
    .add_xaxis(city_job_top20.index.tolist())#添加x轴数据
    .add_yaxis('数据分析就业岗位数量',city_job_top20.values.tolist())# 添加y轴数据
    .set_global_opts(#设置全局参数
        title_opts=opts.TitleOpts(title='一周内Python就业岗位数量'),# 设置标题
        datazoom_opts=opts.DataZoomOpts() # 添加缩放条
    )
)
# 在jupyter notebook中显示
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="be00a436f47c46418a2bf63eb60c4f9d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_be00a436f47c46418a2bf63eb60c4f9d = echarts.init(
#                     document.getElementById('be00a436f47c46418a2bf63eb60c4f9d'), 'white', {renderer: 'canvas'});
#                 var option_be00a436f47c46418a2bf63eb60c4f9d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6570\u636e\u5206\u6790\u5c31\u4e1a\u5c97\u4f4d\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 1608,
#                 1176,
#                 1033,
#                 820,
#                 395,
#                 348,
#                 320,
#                 248,
#                 222,
#                 150,
#                 140,
#                 130,
#                 128,
#                 123,
#                 114,
#                 113,
#                 94,
#                 94,
#                 83,
#                 81
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u636e\u5206\u6790\u5c31\u4e1a\u5c97\u4f4d\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u6570\u636e\u5206\u6790\u5c31\u4e1a\u5c97\u4f4d\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733",
#                 "\u676d\u5dde",
#                 "\u6210\u90fd",
#                 "\u6b66\u6c49",
#                 "\u897f\u5b89",
#                 "\u5357\u4eac",
#                 "\u82cf\u5dde",
#                 "\u5408\u80a5",
#                 "\u91cd\u5e86",
#                 "\u957f\u6c99",
#                 "\u6d4e\u5357",
#                 "\u90d1\u5dde",
#                 "\u592a\u539f",
#                 "\u9752\u5c9b",
#                 "\u5927\u8fde",
#                 "\u4e1c\u839e",
#                 "\u65e0\u9521"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e00\u5468\u5185Python\u5c31\u4e1a\u5c97\u4f4d\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false,
#         "filterMode": "filter"
#     }
# };
#                 chart_be00a436f47c46418a2bf63eb60c4f9d.setOption(option_be00a436f47c46418a2bf63eb60c4f9d);
#         });
#     </script>

# %% [markdown]
# - 结果说明：从结果中可以看出，北京上海广州深圳等一线城市，对数据分析的需求最为旺盛

# %% [markdown]
# ## 哪些公司在招聘数据分析

# %% [markdown]
# ### 示例：获取招聘数据分析岗位最多的 TOP100 公司

# %%
company_list = job.groupby('company_name')['url'].count().sort_values(ascending=False)
company_list_top100 = company_list.head(100)
company_list
# Out:
# company_name
# 北京字节跳动科技有限公司      213
# 武汉益越商务信息咨询有限公司     85
# 北京融汇天诚投资管理有限公司     81
# 字节跳动               67
# 腾讯科技（深圳）有限公司       43
#                  ...
# 宁波利特网络科技有限公司        1
# 宁波塔塔母婴科技有限公司        1
# 宁波奥丞生物科技有限公司        1
# 宁波宝锐进出口有限公司         1
# 龙光基业集团有限公司          1
# Name: url, Length: 4332, dtype: int64

# %% [markdown]
# ### 使用 pyecharts 绘制词云图

# %%
from pyecharts.charts import WordCloud
wc = (
    WordCloud()# 创建词云图对象
    .add(series_name='哪些公司在招聘数据分析程序员',# 添加标题
         data_pair=list(zip(company_list.index.tolist(),company_list.values.tolist())),
         word_size_range=[6,40] # 设置文字大小，注意如果字体太大可能显示不全
        )
    .set_global_opts(# 设置全局参数，标题|字号
        title_opts=opts.TitleOpts(title='哪些公司在招聘数据分析程序员',
                                 title_textstyle_opts=opts.TextStyleOpts(font_size=23))
    )
)
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="f4ab7e05a2194591b84e0e98ff7290e0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_f4ab7e05a2194591b84e0e98ff7290e0 = echarts.init(
#                     document.getElementById('f4ab7e05a2194591b84e0e98ff7290e0'), 'white', {renderer: 'canvas'});
#                 var option_f4ab7e05a2194591b84e0e98ff7290e0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u54ea\u4e9b\u516c\u53f8\u5728\u62db\u8058\u6570\u636e\u5206\u6790\u7a0b\u5e8f\u5458",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 40
#             ],
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5b57\u8282\u8df3\u52a8\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 213,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,145,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u6c49\u76ca\u8d8a\u5546\u52a1\u4fe1\u606f\u54a8\u8be2\u6709\u9650\u516c\u53f8",
#                     "value": 85,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,64,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u878d\u6c47\u5929\u8bda\u6295\u8d44\u7ba1\u7406\u6709\u9650\u516c\u53f8",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,48,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b57\u8282\u8df3\u52a8",
#                     "value": 67,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,64,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u817e\u8baf\u79d1\u6280\uff08\u6df1\u5733\uff09\u6709\u9650\u516c\u53f8",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,3,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e0\u9521\u4e2d\u79d1\u5149\u7535\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,120,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c\u946b\u76db\u5f18\u521b\u8d44\u4ea7\u7ba1\u7406\u6709\u9650\u516c\u53f8",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,79,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u541b\u4e1a\u4f1f\u5408\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,17,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6c60\u521b\u65b0\uff08\u5317\u4eac\uff09\u8f6f\u4ef6\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 26,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,61,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u897f\u5b87\u9686\u5178\u6c47\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,89,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d1d\u58f3\u627e\u623f(\u5317\u4eac)\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 22,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,126,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u4e3d\u5179\u884c\u623f\u5730\u4ea7\u987e\u95ee\u6709\u9650\u516c\u53f8-BJ14",
#                     "value": 21,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,116,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u897f\u91d1\u9886\u534f\u5f18\u4fe1\u606f\u79d1\u6280\u670d\u52a1\u6709\u9650\u516c\u53f8",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,89,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u78d0\u7a0b\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,148,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u9876\u77f3\u57fa\u91d1\u7ba1\u7406\u6709\u9650\u516c\u53f8",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(123,76,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5357\u534e\u76db\u7535\u5b50\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,78,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5408\u80a5\u66e6\u58a8\u5546\u8d38\u6709\u9650\u516c\u53f8",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,51,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5600\u5600\u65e0\u9650\u79d1\u6280\u53d1\u5c55\u6709\u9650\u516c\u53f8",
#                     "value": 18,
#                     "textStyle": {

# %% [markdown]
# ## 岗位数量与平均起薪分布

# %% [markdown]
# ### 数据清洗

# %% [markdown]
# - 提取起薪：
#
# - 原始数据中大多数薪资都以6000-18000形式显示，需要对数据进行处理，提取出起薪，可以使用正则表达式，配合 apply 自定义函数，将工作起薪提取出来

# %% [markdown]
# #### 定义提取工作起薪的函数

# %%
# 数据清洗，提取起薪
import re
def get_salary_down(x):
    if('面议' in x) or ('小时' in x) or ('以' in x):
        return 0
    elif '元' in x:
        return int(re.search(pattern="([0-9]+)-([0-9]+)元/月",string=x).group(1))
    elif '-' in x:
        return int(re.search(pattern="([0-9]+)-([0-9]+)",string=x).group(1))
    else:
        return int(x)

# %% [markdown]
# #### 提取起薪数据之前，首先处理缺失值，将缺失数据去掉并提取起薪

# %%
# 删除salary有缺失值的行
job.dropna(subset=['salary'],inplace=True)
# 提取起薪，添加salary_down列
job['salary_down'] = job.salary.apply(get_salary_down)
job.head(3)
# Out:
#        company_name                                                url  \
# 0      北京盛业恒泰投资有限公司  https://jobs.51job.com/beijing-cyq/104869885.h...
# 1  第一象限市场咨询（北京）有限公司  https://jobs.51job.com/beijing/122888080.html?...
# 2    北京超思电子技术有限责任公司  https://jobs.51job.com/beijing/123358754.html?...
#
#    job_name city      salary experience               company_area  \
# 0   金融数据分析师   北京  6000-18000        NaN  金融/投资/证券,专业服务(咨询、人力资源、财会)
# 1     数据分析师   北京   5000-8000       1年经验  专业服务(咨询、人力资源、财会),互联网/电子商务
# 2  市场数据分析专员   北京  7000-10000       1年经验      电子技术/半导体/集成电路,医疗设备/器械
#
#   company_size                                        description  salary_down
# 0    500-1000人  北京盛业恒泰投资有限公司，注册资金1000万人民币，是一家一站式金融服务的大型企业，旗下有在...         6000
# 1        少于50人  工作职责：1、协同团队完成客户委托的市场研究项目，包括项目的设计、执行、分析、报告撰写和汇报...         5000
# 2    500-1000人  岗位职责：1、业务数据分析l编写月度、季度、年度业务数据分析报告，开展各类与业务销售数据分析...         7000

# %%
# 数值异常值处理
# 查看起薪结构
job['salary_down'].value_counts().sort_index()
# Out:
# 0         141
# 1000        5
# 1500        8
# 1800        1
# 2000       79
#          ...
# 60000       3
# 62500       1
# 70000       2
# 80000       1
# 100000      1
# Name: salary_down, Length: 92, dtype: int64

# %% [markdown]
# - 从处理的起薪中发现，有一些异常数据：
#
# - 特别低的：小于3000
# - 特别高的：大于80000-

# %% [markdown]
# - 异常值处理：直接删除

# %%
job_salary = job.query('salary_down >3000 & salary_down < 80000')
job_salary
# Out:
#              company_name                                                url  \
# 0            北京盛业恒泰投资有限公司  https://jobs.51job.com/beijing-cyq/104869885.h...
# 1        第一象限市场咨询（北京）有限公司  https://jobs.51job.com/beijing/122888080.html?...
# 2          北京超思电子技术有限责任公司  https://jobs.51job.com/beijing/123358754.html?...
# 3            北京麦优尚品科贸有限公司  https://jobs.51job.com/beijing-cyq/79448137.ht...
# 4              北京磐程科技有限公司  https://jobs.51job.com/beijing-cyq/123321410.h...
# ...                   ...                                                ...
# 7919  国汽(北京)智能网联汽车研究院有限公司        https://www.liepin.com/job/1917860209.shtml
# 7920                 美团点评        https://www.liepin.com/job/1924310723.shtml
# 7921           北京快手科技有限公司        https://www.liepin.com/job/1925411961.shtml
# 7922           浙江孚临科技有限公司        https://www.liepin.com/job/1929650055.shtml
# 7923         杭州橙鹰数据技术有限公司        https://www.liepin.com/job/1929479579.shtml
#
#             job_name city       salary experience               company_area  \
# 0            金融数据分析师   北京   6000-18000        NaN  金融/投资/证券,专业服务(咨询、人力资源、财会)
# 1              数据分析师   北京    5000-8000       1年经验  专业服务(咨询、人力资源、财会),互联网/电子商务
# 2           市场数据分析专员   北京   7000-10000       1年经验      电子技术/半导体/集成电路,医疗设备/器械
# 3              数据分析员   北京   8000-10000       1年经验  快速消费品(食品、饮料、化妆品),互联网/电子商务
# 4            金融数据分析师   北京   8000-10000       1年经验                   金融/投资/证券
# ...              ...  ...          ...        ...                        ...
# 7919      数据挖掘与建模工程师   北京  15000-25000       3-5年                        NaN
# 7920  数据挖掘高级工程师/技术专家   北京  50000-80000       经验不限                        NaN
# 7921          数据挖掘专家   深圳  30000-60000       3-5年                        NaN
# 7922       数据挖掘建模工程师   杭州  12000-18000       经验不限                        NaN
# 7923          数据挖掘专家   杭州  18000-30000       3-5年                        NaN
#
#      company_size                                        description  \
# 0       500-1000人  北京盛业恒泰投资有限公司，注册资金1000万人民币，是一家一站式金融服务的大型企业，旗下有在...
# 1           少于50人  工作职责：1、协同团队完成客户委托的市场研究项目，包括项目的设计、执行、分析、报告撰写和汇报...
# 2       500-1000人  岗位职责：1、业务数据分析l编写月度、季度、年度业务数据分析报告，开展各类与业务销售数据分析...
# 3         50-150人  1、根据运营总监安排，实施具体数据分析工作。2、负责数据的审核工作，确保数据的准确性。3、总...
# 4         50-150人  1.人品端正，有责任心，愿与公司一同成长进步；2.以金融行业为最后的事业并为之奋斗一生;3....
# ...           ...                                                ...
# 7919     100-499人  岗位职责：1)基于实车测试和驾驶模拟实验数据，进行针对驾驶人、车辆、环境参数的数据挖掘；2)...
# 7920     10000人以上  工作职责：岗位职责：1、负责小象新零售智能算法，通过算法来提升新零售各个环节效率。具体工作包...
# 7921  5000-10000人                                  数据挖掘算法工程师，要求5年经验起
# 7922       50-99人                                    1、客户营销风控模型建设及运营
# 7923     100-499人  岗位描述：1.深入了解互联网风控产品的产品属性、业务场景、客群特征、风险模式，制定与业务模式...
#
#       salary_down
# 0            6000
# 1            5000
# 2            7000
# 3            8000
# 4            8000
# ...           ...
# 7919        15000
# 7920        50000
# 7921        30000
# 7922        12000
# 7923        18000
#
# [7126 rows x 10 columns]

# %% [markdown]
# ### 数据处理

# %% [markdown]
# #### 将所有城市的薪资和就业岗位数合并到一起

# %%
# 统计所有城市的数据分析岗位数据和起薪的平均值
city_salary = job_salary.groupby('city').agg({'url':'count','salary_down':'mean'})
city_salary.head()
# Out:
#        url   salary_down
# city
# 上海    1119  10795.126005
# 东莞      70   5580.042857
# 北京    1505  13882.837209
# 南京     210   6601.804762
# 南昌      46   6279.217391

# %%
# 修改列标签
city_salary.columns = ['job_count','salary_down']
city_salary.head()
# Out:
#       job_count   salary_down
# city
# 上海         1119  10795.126005
# 东莞           70   5580.042857
# 北京         1505  13882.837209
# 南京          210   6601.804762
# 南昌           46   6279.217391

# %%
# 按照工作岗位数量和起薪降序排列
city_salary = city_salary.sort_values(by=['job_count','salary_down'],ascending=[False,False])
city_salary = city_salary.reset_index()
city_salary.head()
# Out:
#   city  job_count   salary_down
# 0   北京       1505  13882.837209
# 1   上海       1119  10795.126005
# 2   广州        889   7819.732283
# 3   深圳        775  10305.392258
# 4   杭州        358   9756.156425

# %%
from pyecharts.charts import Scatter
from pyecharts.commons.utils import JsCode

sc = Scatter().add_xaxis(# 添加x轴
    city_salary.salary_down.astype(int)
).add_yaxis(# 添加y轴
    series_name='数据分析岗位数量',# y轴数据说明
    y_axis=[list(z) for z in zip(city_salary.job_count,city_salary.city)],# y轴数据：岗位，城市
    label_opts=opts.LabelOpts(# Js代码控制气泡显示提示文字
        formatter=JsCode('function(params){return params.value[2]}')
    )
).set_global_opts(# 全局设置
    title_opts=opts.TitleOpts(title='数据分析就业岗位数量与平均起薪'),# 设置标题
    tooltip_opts=opts.TooltipOpts(# Js代码控制气泡弹窗提示文字
        formatter=JsCode("function(params){return params.value[2]+'平均薪资：'+params.value[0]}")
    ),
    visualmap_opts=opts.VisualMapOpts(# 控制
        type_="size",max_=1500,min_=200,dimension=1
    ),
    xaxis_opts=opts.AxisOpts(min_=6000,name='平均起薪'),#设置x轴起始值以及x轴名字
    yaxis_opts=opts.AxisOpts(min_=300,max_=1550,name='岗位数量')# 设置y轴起始值以及y轴名字
)

sc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="519dcacd840c4184b6ed87b39e318045" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_519dcacd840c4184b6ed87b39e318045 = echarts.init(
#                     document.getElementById('519dcacd840c4184b6ed87b39e318045'), 'white', {renderer: 'canvas'});
#                 var option_519dcacd840c4184b6ed87b39e318045 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u6570\u636e\u5206\u6790\u5c97\u4f4d\u6570\u91cf",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     13882,
#                     1505,
#                     "\u5317\u4eac"
#                 ],
#                 [
#                     10795,
#                     1119,
#                     "\u4e0a\u6d77"
#                 ],
#                 [
#                     7819,
#                     889,
#                     "\u5e7f\u5dde"
#                 ],
#                 [
#                     10305,
#                     775,
#                     "\u6df1\u5733"
#                 ],
#                 [
#                     9756,
#                     358,
#                     "\u676d\u5dde"
#                 ],
#                 [
#                     6711,
#                     302,
#                     "\u6210\u90fd"
#                 ],
#                 [
#                     6946,
#                     247,
#                     "\u6b66\u6c49"
#                 ],
#                 [
#                     5758,
#                     226,
#                     "\u897f\u5b89"
#                 ],
#                 [
#                     6601,
#                     210,
#                     "\u5357\u4eac"
#                 ],
#                 [
#                     6584,
#                     131,
#                     "\u82cf\u5dde"
#                 ],
#                 [
#                     6074,
#                     125,
#                     "\u5408\u80a5"
#                 ],
#                 [
#                     6819,
#                     121,
#                     "\u6d4e\u5357"
#                 ],
#                 [
#                     6529,
#                     109,
#                     "\u957f\u6c99"
#                 ],
#                 [
#                     6096,
#                     107,
#                     "\u91cd\u5e86"
#                 ],
#                 [
#                     5953,
#                     106,
#                     "\u592a\u539f"
#                 ],
#                 [
#                     6866,
#                     93,
#                     "\u90d1\u5dde"
#                 ],
#                 [
#                     5848,
#                     79,
#                     "\u9752\u5c9b"
#                 ],
#                 [
#                     5580,
#                     70,
#                     "\u4e1c\u839e"
#                 ],
#                 [
#                     6272,
#                     68,
#                     "\u5929\u6d25"
#                 ],
#                 [
#                     6992,
#                     64,
#                     "\u53a6\u95e8"
#                 ],
#                 [
#                     6050,
#                     61,
#                     "\u5927\u8fde"
#                 ],
#                 [
#                     6426,
#                     59,
#                     "\u65e0\u9521"
#                 ],
#                 [
#                     6574,
#                     55,
#                     "\u5b81\u6ce2"
#                 ],
#                 [
#                     6993,
#                     53,
#                     "\u798f\u5dde"
#                 ],
#                 [
#                     6279,
#                     46,
#                     "\u5357\u660c"
#                 ],
#                 [
#                     5721,
#                     43,
#                     "\u6c88\u9633"
#                 ],
#                 [
#                     5581,
#                     43,
#                     "\u77f3\u5bb6\u5e84"
#                 ],
#                 [
#                     6063,
#                     32,
#                     "\u6606\u660e"
#                 ],
#                 [
#                     5941,
#                     17,
#                     "\u957f\u6625"
#                 ],
#                 [
#                     6115,
#                     13,
#                     "\u54c8\u5c14\u6ee8"
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(params){return params.value[2]}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u636e\u5206\u6790\u5c97\u4f4d\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u6570\u636e\u5206\u6790\u5c97\u4f4d\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function(params){return params.value[2]+'\u5e73\u5747\u85aa\u8d44\uff1a'+params.value[0]},
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "name": "\u5e73\u5747\u8d77\u85aa",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 6000,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": null
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5c97\u4f4d\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 300,
#             "max": 1550,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6570\u636e\u5206\u6790\u5c31\u4e1a\u5c97\u4f4d\u6570\u91cf\u4e0e\u5e73\u5747\u8d77\u85aa",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 200,
#         "max": 1500

# %% [markdown]
# ## 工作经验需求分析

# %% [markdown]
# ### 数据清洗

# %%
# 提取要求工作经验
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7926 entries, 0 to 7925
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  7926 non-null   object
#  1   url           7926 non-null   object
#  2   job_name      7926 non-null   object
#  3   city          7926 non-null   object
#  4   salary        7926 non-null   object
#  5   experience    7208 non-null   object
#  6   company_area  7556 non-null   object
#  7   company_size  7838 non-null   object
#  8   description   7926 non-null   object
#  9   salary_down   7926 non-null   int64
# dtypes: int64(1), object(9)
# memory usage: 619.3+ KB

# %% [markdown]
# #### 提取要求工作经验数据之前，首先处理缺失值

# %%
job.experience.fillna('未知',inplace=True)
job['experience'].value_counts()
# Out:
# 1-3年       1197
# 1年经验        897
# 不限          854
# 3-5年        763
# 未知          718
# 2年经验        555
# 经验3-5年      519
# 经验不限        483
# 3-4年经验      438
# 无需经验        387
# 经验1-3年      276
# 5-10年       206
# 经验5-10年     155
# 无经验         130
# 5-7年经验      103
# 1年以下         97
# 经验应届毕业生      95
# 10年以上        16
# 经验1年以下       15
# 8-9年经验        9
# 一年以下          8
# 经验10年以上       3
# 10年以上经验       2
# Name: experience, dtype: int64

# %% [markdown]
# #### 定义提取要求工作经验的函数

# %%
def process_experience(x):
    if x in ['1-3年','2年经验','经验1-3年']:
        return '1-3年'
    elif x in ['3-5年','经验3-5年','3-4年经验']:
        return '3-5年'
    elif x in ['1年经验', '1年以下', '经验1年以下', '一年以下', '经验应届毕业生','不限','经验不限','无需经验','无经验']:
        return '一年以下/应届生/经验不限'
    elif x in ['5-10年','经验5-10年','5-7年经验','8-9年经验','10年以上经验','10年以上','经验10年以上']:
        return '5年以上'
    else:
        return x

# %% [markdown]
# #### 提取要求工作经验

# %%
job['exp'] = job.experience.apply(process_experience)
job_experience = job['exp'].value_counts()
job_experience
# Out:
# 一年以下/应届生/经验不限    2966
# 1-3年             2028
# 3-5年             1720
# 未知                718
# 5年以上              494
# Name: exp, dtype: int64

# %% [markdown]
# ### 绘制饼状图

# %%
from pyecharts.charts import Pie
pie = Pie().add(
    series_name='经验要求',
    data_pair=[
        list(z) for z in zip(job_experience.index.to_list(),job_experience.values.tolist())
    ],
    radius=['50%','70%'],
    label_opts=opts.LabelOpts(is_show=False,position='center')
).set_global_opts(
    title_opts=opts.TitleOpts(title='数据分析工作经验需求'),
    legend_opts=opts.LegendOpts(pos_left='right',orient='vertical')
).set_series_opts(
    tooltip_opts=opts.TooltipOpts(
        trigger='item',
        formatter="{a}<br/>{b}:{c} ({d}%)"
    )
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="83acc8f39ee74f8e9718e46c59b121c0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_83acc8f39ee74f8e9718e46c59b121c0 = echarts.init(
#                     document.getElementById('83acc8f39ee74f8e9718e46c59b121c0'), 'white', {renderer: 'canvas'});
#                 var option_83acc8f39ee74f8e9718e46c59b121c0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u7ecf\u9a8c\u8981\u6c42",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4e00\u5e74\u4ee5\u4e0b/\u5e94\u5c4a\u751f/\u7ecf\u9a8c\u4e0d\u9650",
#                     "value": 2966
#                 },
#                 {
#                     "name": "1-3\u5e74",
#                     "value": 2028
#                 },
#                 {
#                     "name": "3-5\u5e74",
#                     "value": 1720
#                 },
#                 {
#                     "name": "\u672a\u77e5",
#                     "value": 718
#                 },
#                 {
#                     "name": "5\u5e74\u4ee5\u4e0a",
#                     "value": 494
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": false,
#                 "position": "center",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a}<br/>{b}:{c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e00\u5e74\u4ee5\u4e0b/\u5e94\u5c4a\u751f/\u7ecf\u9a8c\u4e0d\u9650",
#                 "1-3\u5e74",
#                 "3-5\u5e74",
#                 "\u672a\u77e5",
#                 "5\u5e74\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "right",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u6570\u636e\u5206\u6790\u5de5\u4f5c\u7ecf\u9a8c\u9700\u6c42",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_83acc8f39ee74f8e9718e46c59b121c0.setOption(option_83acc8f39ee74f8e9718e46c59b121c0);
#         });
#     </script>

# %% [markdown]
# # 总结
# - echarts 是基于 js 的开源可视化库，pyecharts 是 echarts 的 python 封装，利用 pyecharts 可以绘制具备交互性的炫酷图形
# - pyecharts 1.*版本的绘图 api 还是具有一定规律的
# - Bar()、Pie() .... 创建绘图对象
# - .add()、.add_xaxis()、.add_yaxis()添加数据
# - .set_global_opts() 设置全局参数
# - .render_notebook()：在notebook中绘制
# - .render()：生成文件
# - 更加详细的 API 可以参考 pyecharts 的官方文档和案例
